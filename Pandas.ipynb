# %%
import pandas as pd
df=pd.read_csv("pokemon_data.csv",index_col="Pokemon").squeeze()

# %%
df.index
# Out:
# Index(['Bulbasaur', 'Ivysaur', 'Venusaur', 'Charmander', 'Charmeleon',
#        'Charizard', 'Squirtle', 'Wartortle', 'Blastoise', 'Caterpie',
#        ...
#        'Bergmite', 'Avalugg', 'Noibat', 'Noivern', 'Xerneas', 'Yveltal',
#        'Zygarde', 'Diancie', 'Hoopa', 'Volcanion'],
#       dtype='object', name='Pokemon', length=721)

# %%
df.values
# Out:
# array(['Grass', 'Grass', 'Grass', 'Fire', 'Fire', 'Fire', 'Water',
#        'Water', 'Water', 'Bug', 'Bug', 'Bug', 'Bug', 'Bug', 'Bug',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Poison', 'Poison', 'Electric', 'Electric', 'Ground',
#        'Ground', 'Poison', 'Poison', 'Poison', 'Poison', 'Poison',
#        'Poison', 'Fairy', 'Fairy', 'Fire', 'Fire', 'Normal', 'Normal',
#        'Poison', 'Poison', 'Grass', 'Grass', 'Grass', 'Bug', 'Bug', 'Bug',
#        'Bug', 'Ground', 'Ground', 'Normal', 'Normal', 'Water', 'Water',
#        'Fighting', 'Fighting', 'Fire', 'Fire', 'Water', 'Water', 'Water',
#        'Psychic', 'Psychic', 'Psychic', 'Fighting', 'Fighting',
#        'Fighting', 'Grass', 'Grass', 'Grass', 'Water', 'Water', 'Rock',
#        'Rock', 'Rock', 'Fire', 'Fire', 'Water', 'Water', 'Electric',
#        'Electric', 'Normal', 'Normal', 'Normal', 'Water', 'Water',
# ...

# %%
df.value_counts(normalize=True)
# Out:
# Water       0.145631
# Normal      0.128988
# Grass       0.091540
# Bug         0.087379
# Fire        0.065187
# Psychic     0.065187
# Rock        0.056865
# Electric    0.049931
# Ground      0.041609
# Poison      0.038835
# Dark        0.038835
# Fighting    0.034674
# Dragon      0.033287
# Ghost       0.031900
# Ice         0.031900
# Steel       0.030513
# Fairy       0.023578
# Flying      0.004161
# Name: Type, dtype: float64

# %%
df[[0,4,8]]
# Out:
# Pokemon
# Bulbasaur     Grass
# Charmeleon     Fire
# Blastoise     Water
# Name: Type, dtype: object

# %%
df=pd.read_csv("NbaInfo.csv")

# %%
df.dropna(inplace=True)

# %%
collegeSeries=df["College"]
collegeSeries
# Out:
# 0              Texas
# 1          Marquette
# 3      Georgia State
# 6                LSU
# 7            Gonzaga
#            ...
# 449             Duke
# 451           Dayton
# 452         Kentucky
# 453           Butler
# 456           Kansas
# Name: College, Length: 364, dtype: object

# %%
collegeSeries.apply(len)
# Out:
# 0       5
# 1       9
# 3      13
# 6       3
# 7       7
#        ..
# 449     4
# 451     6
# 452     8
# 453     6
# 456     6
# Name: College, Length: 364, dtype: int64

# %%
##Create a function. If the college name starts with leter with T, M, B, then we have to print invitation accepted else print not a
#accepted 

def func(x):
    if str(x[0].upper()) in ('T','M','B'):
        return "accepted"
    else:
        return "not accepted"
collegeSeries.apply(func)
# Out:
# 0          accepted
# 1          accepted
# 3      not accepted
# 6      not accepted
# 7      not accepted
#            ...
# 449    not accepted
# 451    not accepted
# 452    not accepted
# 453        accepted
# 456    not accepted
# Name: College, Length: 364, dtype: object

# %%
map_dict={"Texas":"Invited","Butler":"not invited"}
collegeSeries.map(map_dict)
# Out:
# 0          Invited
# 1              NaN
# 3              NaN
# 6              NaN
# 7              NaN
#           ...
# 449            NaN
# 451            NaN
# 452            NaN
# 453    not invited
# 456            NaN
# Name: College, Length: 364, dtype: object

# %%
collegeSeries.unique
# Out:
# <bound method Series.unique of 0              Texas
# 1          Marquette
# 3      Georgia State
# 6                LSU
# 7            Gonzaga
#            ...
# 449             Duke
# 451           Dayton
# 452         Kentucky
# 453           Butler
# 456           Kansas
# Name: College, Length: 364, dtype: object>

# %%
collegeSeries.unique()
# Out:
# array(['Texas', 'Marquette', 'Georgia State', 'LSU', 'Gonzaga',
#        'Louisville', 'Oklahoma State', 'Ohio State', 'Washington',
#        'Kentucky', 'North Carolina', 'Arizona', 'Georgia Tech',
#        'Cincinnati', 'Miami (FL)', 'Stanford', 'Syracuse', 'Saint Louis',
#        'Kansas', 'Georgetown', 'Texas A&M', 'UCLA', 'UNLV',
#        'Wichita State', "Saint Joseph's", 'Notre Dame', 'Norfolk State',
#        'Duke', 'Murray State', 'Tennessee State', 'Bowling Green',
#        'Purdue', 'Wake Forest', 'Michigan', 'Missouri', 'USC',
#        'Villanova', 'Rider', 'Utah', 'Belmont', 'Davidson', 'Vanderbilt',
#        'Michigan State', 'Florida', 'Washington State', 'Arizona State',
#        'Oklahoma', 'Wyoming', "St. John's", 'Maryland', 'Wisconsin',
#        'Utah Valley', 'North Carolina State', 'UC Santa Barbara',
#        'Baylor', 'Connecticut', 'Oregon State', 'New Mexico', 'Oregon',
#        'Creighton', 'Arkansas', 'Memphis', "Saint Mary's", 'Tennessee',
# ...

# %%
collegeSeries.nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0              Texas
# 1          Marquette
# 3      Georgia State
# 6                LSU
# 7            Gonzaga
#            ...
# 449             Duke
# 451           Dayton
# 452         Kentucky
# 453           Butler
# 456           Kansas
# Name: College, Length: 364, dtype: object>

# %%
 collegeSeries.nunique() #Return no of unique values
# Out:
# 115

# %%
collegeSeries.describe()
# Out:
# count          364
# unique         115
# top       Kentucky
# freq            22
# Name: College, dtype: object

# %%
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary
# 0            Texas  7730337.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 364 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      364 non-null    object
#  1   Team      364 non-null    object
#  2   Number    364 non-null    float64
#  3   Position  364 non-null    object
#  4   Age       364 non-null    float64
#  5   Height    364 non-null    object
#  6   Weight    364 non-null    float64
#  7   College   364 non-null    object
#  8   Salary    364 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 28.4+ KB

# %%
df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  364.000000  364.000000  364.000000  3.640000e+02
# mean    16.829670   26.615385  219.785714  4.620311e+06
# std     14.994162    4.233591   24.793099  5.119716e+06
# min      0.000000   19.000000  161.000000  5.572200e+04
# 25%      5.000000   24.000000  200.000000  1.000000e+06
# 50%     12.000000   26.000000  220.000000  2.515440e+06
# 75%     25.000000   29.000000  240.000000  6.149694e+06
# max     99.000000   40.000000  279.000000  2.287500e+07

# %%
df.dropna(how='any')
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary
# 0            Texas  7730337.0
# ...

# %%
df.dropna(how='all') #By default axis=0
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary
# 0            Texas  7730337.0
# ...

# %%
df.dropna(subset=["Salary","College"])
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary
# 0            Texas  7730337.0
# ...

# %%
df.dropna(thresh=5)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#            College     Salary
# 0            Texas  7730337.0
# ...

# %%
df['Salary']=df['Salary'].astype("int64")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 364 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      364 non-null    object
#  1   Team      364 non-null    object
#  2   Number    364 non-null    float64
#  3   Position  364 non-null    object
#  4   Age       364 non-null    float64
#  5   Height    364 non-null    object
#  6   Weight    364 non-null    float64
#  7   College   364 non-null    object
#  8   Salary    364 non-null    int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 28.4+ KB

# %%
df['Number']=df['Number'].astype('int')
df['Age']=df['Age'].astype('int')

# %%
df.shape #return numbers of rows and columns in a dataframe
# Out:
# (364, 9)

# %%
df.dropna(axis=1,thresh=df.shape[0]*0.9)
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25    6-2   180.0
# 1      Jae Crowder  Boston Celtics      99       SF   25    6-6   235.0
# 3      R.J. Hunter  Boston Celtics      28       SG   22    6-5   185.0
# 6    Jordan Mickey  Boston Celtics      55       PF   21    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics      41        C   25    7-0   238.0
# ..             ...             ...     ...      ...  ...    ...     ...
# 449    Rodney Hood       Utah Jazz       5       SG   23    6-8   206.0
# 451  Chris Johnson       Utah Jazz      23       SF   26    6-6   206.0
# 452     Trey Lyles       Utah Jazz      41       PF   20   6-10   234.0
# 453   Shelvin Mack       Utah Jazz       8       PG   26    6-3   203.0
# 456    Jeff Withey       Utah Jazz      24        C   26    7-0   231.0
#
#            College   Salary
# 0            Texas  7730337
# 1        Marquette  6796117
# ...

# %%
#filling null values
df[["Salary","Number"]].fillna(0)
# Out:
#       Salary  Number
# 0    7730337       0
# 1    6796117      99
# 3    1148640      28
# 6    1170960      55
# 7    2165160      41
# ..       ...     ...
# 449  1348440       5
# 451   981348      23
# 452  2239800      41
# 453  2433333       8
# 456   947276      24
#
# [364 rows x 2 columns]

# %%
df['Salary'].hasnans
# Out:
# False

# %%
df.nunique()
# Out:
# Name        364
# Team         30
# Number       51
# Position      5
# Age          22
# Height       17
# Weight       76
# College     115
# Salary      256
# dtype: int64

# %%
df.dtypes
# Out:
# Name         object
# Team         object
# Number        int32
# Position     object
# Age           int32
# Height       object
# Weight      float64
# College      object
# Salary        int64
# dtype: object

# %%
df['Position']=df['Position'].astype('category')

# %%
df['Team']=df['Team'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 364 entries, 0 to 456
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      364 non-null    object
#  1   Team      364 non-null    category
#  2   Number    364 non-null    int32
#  3   Position  364 non-null    category
#  4   Age       364 non-null    int32
#  5   Height    364 non-null    object
#  6   Weight    364 non-null    float64
#  7   College   364 non-null    object
#  8   Salary    364 non-null    int64
# dtypes: category(2), float64(1), int32(2), int64(1), object(3)
# memory usage: 22.1+ KB

# %%
df.sort_values(by=['Name','Salary'],ascending=[True,False])
# Out:
#                     Name                    Team  Number Position  Age Height  \
# 152         Aaron Brooks           Chicago Bulls       0       PG   31    6-0
# 356         Aaron Gordon           Orlando Magic       0       PF   20    6-9
# 328       Aaron Harrison       Charlotte Hornets       9       SG   21    6-6
# 404        Adreian Payne  Minnesota Timberwolves      33       PF   25   6-10
# 312           Al Horford           Atlanta Hawks      15        C   30   6-10
# ..                   ...                     ...     ...      ...  ...    ...
# 141  Willie Cauley-Stein        Sacramento Kings       0        C   22    7-0
# 25           Willie Reed           Brooklyn Nets      33       PF   26   6-10
# 386      Wilson Chandler          Denver Nuggets      21       SF   29    6-8
# 402          Zach LaVine  Minnesota Timberwolves       8       PG   21    6-5
# 271        Zach Randolph       Memphis Grizzlies      50       PF   34    6-9
#
# ...

# %%
df[df.duplicated(subset=["Team"],keep=False)]
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25    6-2   180.0
# 1      Jae Crowder  Boston Celtics      99       SF   25    6-6   235.0
# 3      R.J. Hunter  Boston Celtics      28       SG   22    6-5   185.0
# 6    Jordan Mickey  Boston Celtics      55       PF   21    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics      41        C   25    7-0   238.0
# ..             ...             ...     ...      ...  ...    ...     ...
# 449    Rodney Hood       Utah Jazz       5       SG   23    6-8   206.0
# 451  Chris Johnson       Utah Jazz      23       SF   26    6-6   206.0
# 452     Trey Lyles       Utah Jazz      41       PF   20   6-10   234.0
# 453   Shelvin Mack       Utah Jazz       8       PG   26    6-3   203.0
# 456    Jeff Withey       Utah Jazz      24        C   26    7-0   231.0
#
#            College   Salary
# 0            Texas  7730337
# 1        Marquette  6796117
# ...

# %%
import numpy as np
a=np.array([[2,3,4],[4,5,6]])
a.shape
# Out:
# (2, 3)

# %%
x=np.array([[1,2,3],[4,5,6]])
y=np.array([1,2,3])
y+x
# Out:
# array([[2, 4, 6],
#        [5, 7, 9]])

# %%
a=np.array([1,2,3])
a.ndim
# Out:
# 1

# %%
a.reshape(1,3)
a.ndim
# Out:
# 1

# %%
a
# Out:
# array([1, 2, 3])

# %%
df
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25    6-2   180.0
# 1      Jae Crowder  Boston Celtics      99       SF   25    6-6   235.0
# 3      R.J. Hunter  Boston Celtics      28       SG   22    6-5   185.0
# 6    Jordan Mickey  Boston Celtics      55       PF   21    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics      41        C   25    7-0   238.0
# ..             ...             ...     ...      ...  ...    ...     ...
# 449    Rodney Hood       Utah Jazz       5       SG   23    6-8   206.0
# 451  Chris Johnson       Utah Jazz      23       SF   26    6-6   206.0
# 452     Trey Lyles       Utah Jazz      41       PF   20   6-10   234.0
# 453   Shelvin Mack       Utah Jazz       8       PG   26    6-3   203.0
# 456    Jeff Withey       Utah Jazz      24        C   26    7-0   231.0
#
#            College   Salary
# 0            Texas  7730337
# 1        Marquette  6796117
# ...

# %%
df[(df["Age"].isin((25,28,30))) &((df['Salary']>=2500000) & (df['Salary']<=4000000))]
# Out:
#                   Name                    Team  Number Position  Age Height  \
# 44    Derrick Williams         New York Knicks      23       PF   25    6-8
# 71       Terrence Ross         Toronto Raptors      31       SF   25    6-7
# 88   Marreese Speights   Golden State Warriors       5        C   28   6-10
# 201        Jordan Hill          Indiana Pacers      27        C   28   6-10
# 216        John Henson         Milwaukee Bucks      31       PF   25   6-11
# 293   Quincy Pondexter    New Orleans Pelicans      20       SF   28    6-7
# 383     Darrell Arthur          Denver Nuggets       0       PF   28    6-9
# 384      D.J. Augustin          Denver Nuggets      12       PG   28    6-0
# 385        Will Barton          Denver Nuggets       5       SF   25    6-6
# 421     Anthony Morrow   Oklahoma City Thunder       2       SG   30    6-5
# 440      Brian Roberts  Portland Trail Blazers       2       PG   30    6-1
#
#      Weight         College   Salary
# ...

# %%
df[df['Salary'].between(2500000,4000000)]
# Out:
#                          Name                    Team  Number Position  Age  \
# 9                Marcus Smart          Boston Celtics      36       PG   22
# 10            Jared Sullinger          Boston Celtics       7        C   24
# 12                Evan Turner          Boston Celtics      11       SG   27
# 14               Tyler Zeller          Boston Celtics      44        C   26
# 39               Kyle O'Quinn         New York Knicks       9       PF   26
# 44           Derrick Williams         New York Knicks      23       PF   25
# 55               Nerlens Noel      Philadelphia 76ers       4       PF   22
# 58               Nik Stauskas      Philadelphia 76ers      11       SG   22
# 65              James Johnson         Toronto Raptors       3       PF   29
# 71              Terrence Ross         Toronto Raptors      31       SF   25
# 77            Harrison Barnes   Golden State Warriors      40       SF   24
# ...

# %%
df[df['Name'].between('Brook Lopez','E')]
# Out:
#                    Name                    Team  Number Position  Age Height  \
# 23          Brook Lopez           Brooklyn Nets      11        C   28    7-0
# 24     Chris McCullough           Brooklyn Nets       1       PF   21   6-11
# 28         Donald Sloan           Brooklyn Nets      15       PG   28    6-3
# 33      Carmelo Anthony         New York Knicks       7       SF   32    6-8
# 35     Cleanthony Early         New York Knicks      11       SF   25    6-8
# 44     Derrick Williams         New York Knicks      23       PF   25    6-8
# 52          Carl Landry      Philadelphia 76ers       7       PF   32    6-9
# 60       Christian Wood      Philadelphia 76ers      35       PF   20   6-11
# 63      DeMarre Carroll         Toronto Raptors       5       SF   29    6-8
# 64        DeMar DeRozan         Toronto Raptors      10       SG   26    6-7
# 66          Cory Joseph         Toronto Raptors       6       PG   24    6-3
# ...

# %% [markdown]
# belongs to the team Portland Trail Blazers,Boston Celtics and salary is 3500000

# %%
df[(df['Team'].isin(('Portland Trail Blazers','Boston Celtics'))) &(df['Salary']>3500000)][['Name','Team','Height','Salary']]
# Out:
#                  Name                    Team Height   Salary
# 0       Avery Bradley          Boston Celtics    6-2  7730337
# 1         Jae Crowder          Boston Celtics    6-6  6796117
# 11      Isaiah Thomas          Boston Celtics    5-9  6912869
# 428   Al-Farouq Aminu  Portland Trail Blazers    6-9  8042895
# 431          Ed Davis  Portland Trail Blazers   6-10  6980802
# 433  Gerald Henderson  Portland Trail Blazers    6-5  6000000
# 434       Chris Kaman  Portland Trail Blazers    7-0  5016000
# 436    Damian Lillard  Portland Trail Blazers    6-3  4236287

# %%
df.sort_index(inplace=True)

# %%
df.sort_values(by='Team').drop_duplicates()
# Out:
#                  Name                Team  Number Position  Age Height  \
# 310  Tim Hardaway Jr.       Atlanta Hawks      10       SG   24    6-6
# 319        Mike Scott       Atlanta Hawks      32       PF   27    6-8
# 323       Jeff Teague       Atlanta Hawks       0       PG   27    6-2
# 316      Mike Muscala       Atlanta Hawks      31       PF   24   6-11
# 309     Kent Bazemore       Atlanta Hawks      24       SF   26    6-5
# ..                ...                 ...     ...      ...  ...    ...
# 380    Garrett Temple  Washington Wizards      17       SG   30    6-6
# 381   Marcus Thornton  Washington Wizards      15       SF   29    6-4
# 382         John Wall  Washington Wizards       2       PG   25    6-4
# 368     Alan Anderson  Washington Wizards       6       SG   33    6-6
# 369      Bradley Beal  Washington Wizards       3       SG   22    6-5
#
#      Weight         College    Salary
# 310   205.0        Michigan   1304520
# ...

# %%
a=np.array([[1,2,3],[4,5,6]])

# %%
a.mean(axis=1)
# Out:
# array([2., 5.])

# %%
a.mean(axis=0)
# Out:
# array([2.5, 3.5, 4.5])

# %%
df
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25    6-2   180.0
# 1      Jae Crowder  Boston Celtics      99       SF   25    6-6   235.0
# 3      R.J. Hunter  Boston Celtics      28       SG   22    6-5   185.0
# 6    Jordan Mickey  Boston Celtics      55       PF   21    6-8   235.0
# 7     Kelly Olynyk  Boston Celtics      41        C   25    7-0   238.0
# ..             ...             ...     ...      ...  ...    ...     ...
# 449    Rodney Hood       Utah Jazz       5       SG   23    6-8   206.0
# 451  Chris Johnson       Utah Jazz      23       SF   26    6-6   206.0
# 452     Trey Lyles       Utah Jazz      41       PF   20   6-10   234.0
# 453   Shelvin Mack       Utah Jazz       8       PG   26    6-3   203.0
# 456    Jeff Withey       Utah Jazz      24        C   26    7-0   231.0
#
#            College   Salary
# 0            Texas  7730337
# 1        Marquette  6796117
# ...

# %%
df.insert(1,column="New_Nae",value="Mr "+df.Name)

# %%
df
# Out:
#               Name          New_Nae            Team  Number Position  Age  \
# 0    Avery Bradley  MrAvery Bradley  Boston Celtics       0       PG   25
# 1      Jae Crowder    MrJae Crowder  Boston Celtics      99       SF   25
# 3      R.J. Hunter    MrR.J. Hunter  Boston Celtics      28       SG   22
# 6    Jordan Mickey  MrJordan Mickey  Boston Celtics      55       PF   21
# 7     Kelly Olynyk   MrKelly Olynyk  Boston Celtics      41        C   25
# ..             ...              ...             ...     ...      ...  ...
# 449    Rodney Hood    MrRodney Hood       Utah Jazz       5       SG   23
# 451  Chris Johnson  MrChris Johnson       Utah Jazz      23       SF   26
# 452     Trey Lyles     MrTrey Lyles       Utah Jazz      41       PF   20
# 453   Shelvin Mack   MrShelvin Mack       Utah Jazz       8       PG   26
# 456    Jeff Withey    MrJeff Withey       Utah Jazz      24        C   26
#
#     Height  Weight        College   Salary
# ...

# %%
df.rename(columns={'Team':"New Team",'Position':'New Position'})
# Out:
#               Name          New_Nae        New Team  Number New Position  Age  \
# 0    Avery Bradley  MrAvery Bradley  Boston Celtics       0           PG   25
# 1      Jae Crowder    MrJae Crowder  Boston Celtics      99           SF   25
# 3      R.J. Hunter    MrR.J. Hunter  Boston Celtics      28           SG   22
# 6    Jordan Mickey  MrJordan Mickey  Boston Celtics      55           PF   21
# 7     Kelly Olynyk   MrKelly Olynyk  Boston Celtics      41            C   25
# ..             ...              ...             ...     ...          ...  ...
# 449    Rodney Hood    MrRodney Hood       Utah Jazz       5           SG   23
# 451  Chris Johnson  MrChris Johnson       Utah Jazz      23           SF   26
# 452     Trey Lyles     MrTrey Lyles       Utah Jazz      41           PF   20
# 453   Shelvin Mack   MrShelvin Mack       Utah Jazz       8           PG   26
# 456    Jeff Withey    MrJeff Withey       Utah Jazz      24            C   26
#
# ...

# %%
df.where(df["Number"]>100)
# Out:
#     Name New_Nae Team  Number Position  Age Height  Weight College  Salary
# 0    NaN     NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 1    NaN     NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 3    NaN     NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 6    NaN     NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 7    NaN     NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# ..   ...     ...  ...     ...      ...  ...    ...     ...     ...     ...
# 449  NaN     NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 451  NaN     NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 452  NaN     NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 453  NaN     NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
# 456  NaN     NaN  NaN     NaN      NaN  NaN    NaN     NaN     NaN     NaN
#
# [364 rows x 10 columns]

# %%
def conc(x,y):
    return x+y
df['conca']=df.apply(lambda a:conc(a['Name'],a['College']),axis=1)
    
df['conca']
# Out:
# 0            Avery BradleyTexas
# 1          Jae CrowderMarquette
# 3      R.J. HunterGeorgia State
# 6              Jordan MickeyLSU
# 7           Kelly OlynykGonzaga
#                  ...
# 449             Rodney HoodDuke
# 451         Chris JohnsonDayton
# 452          Trey LylesKentucky
# 453          Shelvin MackButler
# 456           Jeff WitheyKansas
# Name: conca, Length: 364, dtype: object
